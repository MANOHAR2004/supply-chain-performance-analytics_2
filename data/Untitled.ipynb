# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    "C:\Users\lenovo\OneDrive\Desktop\supply-chain-performance-analytics\data\raw_data\SCMS_Delivery_History_Dataset_20150929.csv" , encoding="latin1"
)
# Out:
#   Cell In[7], line 5
#     "C:\Users\lenovo\OneDrive\Desktop\supply-chain-performance-analytics\data\raw_data\SCMS_Delivery_History_Dataset_20150929.csv" , encoding="latin1"
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
